# %% [markdown]
# # Toponyms and their Countries
#
# By Eduardo Graells-Garrido.
#
# In this notebook we generate a dictionary of {place_uri => country_uri} so in other notebooks, when we need to determine the country of origin of a biography, we do not have to parse the entire database again looking for this information.
#
# The result is one dictionary per each language. Equivalences between languages have not been resolved yet.

# %%
from __future__ import print_function, unicode_literals
import gzip
import dbpedia_config
import ujson as json
from dbpedia_utils import iter_entities_from

# %%
data_folder = dbpedia_config.DATA_FOLDER
target_folder = dbpedia_config.TARGET_FOLDER
languages = dbpedia_config.LANGUAGES

# %%
def create_country_dictionary(language):
    instance_types = '{1}/instance_types_{0}.nt.bz2'.format(language, data_folder)
    properties = '{1}/mappingbased_properties_{0}.nt.bz2'.format(language, data_folder)

    print(instance_types)
    country_names = set()

    for i, ent in enumerate(iter_entities_from(instance_types)):
        if 'http://dbpedia.org/ontology/Country' in ent['22-rdf-syntax-ns#type']:
            country_names.add(ent['resource'])

    print(len(country_names))

    places = set()

    for i, ent in enumerate(iter_entities_from(instance_types)):
        if 'http://dbpedia.org/ontology/Place' in ent['22-rdf-syntax-ns#type']:
            places.add(ent['resource'])

    print(len(places))

    countries = {}

    for i, ent in enumerate(iter_entities_from(properties)):
        resource = ent['resource']

        if resource not in places:
            continue

        if 'country' not in ent:
            continue
        
        try:
            c = next((ent['country'] & country_names).__iter__())
        except StopIteration:
            # doesn't have a valid country URI attribute
            continue

        countries[resource] = c

    print(len(countries))

    with gzip.open('{0}/countries_{1}.json.gz'.format(target_folder, language), 'wt') as f:
        json.dump(countries, f)

# %%
import os

# %%
for lang in languages:
    if not os.path.exists('{0}/countries_{1}.json.gz'.format(target_folder, lang)):
        create_country_dictionary(lang)
    else:
        print(lang, 'already exists')
# Out:
# en already exists
# /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_bg.nt.bz2
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_bg.nt.bz2
# 279
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_bg.nt.bz2
# 18659
# reading /media/egraells/113A88F901102CA6/data/dbpedia//mappingbased_properties_bg.nt.bz2
# 0
# /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_ca.nt.bz2
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_ca.nt.bz2
# 0
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_ca.nt.bz2
# 80017
# reading /media/egraells/113A88F901102CA6/data/dbpedia//mappingbased_properties_ca.nt.bz2
# 0
# /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_cs.nt.bz2
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_cs.nt.bz2
# 300
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_cs.nt.bz2
# 27944
# reading /media/egraells/113A88F901102CA6/data/dbpedia//mappingbased_properties_cs.nt.bz2
# 5458
# /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_de.nt.bz2
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_de.nt.bz2
# 466
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_de.nt.bz2
# 270224
# reading /media/egraells/113A88F901102CA6/data/dbpedia//mappingbased_properties_de.nt.bz2
# 2071
# /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_es.nt.bz2
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_es.nt.bz2
# 273
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_es.nt.bz2
# 197539
# reading /media/egraells/113A88F901102CA6/data/dbpedia//mappingbased_properties_es.nt.bz2
# 89361
# /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_eu.nt.bz2
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_eu.nt.bz2
# 0
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_eu.nt.bz2
# 53146
# reading /media/egraells/113A88F901102CA6/data/dbpedia//mappingbased_properties_eu.nt.bz2
# 0
# /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_fr.nt.bz2
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_fr.nt.bz2
# 421
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_fr.nt.bz2
# 192401
# reading /media/egraells/113A88F901102CA6/data/dbpedia//mappingbased_properties_fr.nt.bz2
# 118999
# /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_hu.nt.bz2
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_hu.nt.bz2
# 526
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_hu.nt.bz2
# 31581
# reading /media/egraells/113A88F901102CA6/data/dbpedia//mappingbased_properties_hu.nt.bz2
# 2339
# /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_id.nt.bz2
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_id.nt.bz2
# 31
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_id.nt.bz2
# 57666
# reading /media/egraells/113A88F901102CA6/data/dbpedia//mappingbased_properties_id.nt.bz2
# 4
# /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_it.nt.bz2
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_it.nt.bz2
# 204
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_it.nt.bz2
# 189409
# reading /media/egraells/113A88F901102CA6/data/dbpedia//mappingbased_properties_it.nt.bz2
# 1305
# /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_ja.nt.bz2
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_ja.nt.bz2
# 0
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_ja.nt.bz2
# 43396
# reading /media/egraells/113A88F901102CA6/data/dbpedia//mappingbased_properties_ja.nt.bz2
# 0
# /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_ko.nt.bz2
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_ko.nt.bz2
# 223
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_ko.nt.bz2
# 10342
# reading /media/egraells/113A88F901102CA6/data/dbpedia//mappingbased_properties_ko.nt.bz2
# 0
# /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_nl.nt.bz2
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_nl.nt.bz2
# 1853
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_nl.nt.bz2
# 323625
# reading /media/egraells/113A88F901102CA6/data/dbpedia//mappingbased_properties_nl.nt.bz2
# 255112
# /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_pl.nt.bz2
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_pl.nt.bz2
# 1153
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_pl.nt.bz2
# 200730
# reading /media/egraells/113A88F901102CA6/data/dbpedia//mappingbased_properties_pl.nt.bz2
# 52065
# /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_pt.nt.bz2
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_pt.nt.bz2
# 303
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_pt.nt.bz2
# 133475
# reading /media/egraells/113A88F901102CA6/data/dbpedia//mappingbased_properties_pt.nt.bz2
# 1943
# /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_ru.nt.bz2
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_ru.nt.bz2
# 294
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_ru.nt.bz2
# 206957
# reading /media/egraells/113A88F901102CA6/data/dbpedia//mappingbased_properties_ru.nt.bz2
# 58275
# /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_tr.nt.bz2
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_tr.nt.bz2
# 287
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_tr.nt.bz2
# 10713
# reading /media/egraells/113A88F901102CA6/data/dbpedia//mappingbased_properties_tr.nt.bz2
# 1391
# /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_ar.nt.bz2
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_ar.nt.bz2
# 307
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_ar.nt.bz2
# 28338
# reading /media/egraells/113A88F901102CA6/data/dbpedia//mappingbased_properties_ar.nt.bz2
# 1840
# /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_el.nt.bz2
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_el.nt.bz2
# 278
# reading /media/egraells/113A88F901102CA6/data/dbpedia//instance_types_el.nt.bz2
# 7518
# reading /media/egraells/113A88F901102CA6/data/dbpedia//mappingbased_properties_el.nt.bz2
# 1884
